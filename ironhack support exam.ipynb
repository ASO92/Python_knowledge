# %% [markdown]
# ![image.png](attachment:image.png)

# %%
45/21 #Minutos por pregunta
# Out:
# 2.142857142857143

# %%
12*5, 45/2
# Out:
# (60, 22.5)

# %%
840/60
# Out:
# 14.0

# %%
32*2
# Out:
# 64

# %%
11 + 5
# Out:
# 16

# %%
18+9
# Out:
# 27

# %%
22-13
# Out:
# 9

# %%
22+17
# Out:
# 39
